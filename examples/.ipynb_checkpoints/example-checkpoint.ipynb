# %% [markdown]
# # Implementation of the LR Range test

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from lrfinder import LRFinder

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Load Dataset

# %%
BATCH = 32

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_ds = train_ds.shuffle(buffer_size=len(train_images))
train_ds = train_ds.batch(BATCH)
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE)


test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_ds = test_ds.batch(BATCH)
test_ds = test_ds.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Create a Model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
  tf.keras.layers.Dense(128,activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=['accuracy'],
)

# %% [markdown]
# ## Find Learning Rate

# %% [markdown]
# Explore learning rate from `start_lr` to `end_lr` over five `epochs`.

# %%
STEPS_PER_EPOCH = np.ceil(len(train_images) / BATCH)

# %%
lr_finder = LRFinder(model)
lr_finder.find(train_ds, start_lr=1e-6, end_lr=1, epochs=5,
               steps_per_epoch=STEPS_PER_EPOCH)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.0695 - accuracy: 0.3361
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7860 - accuracy: 0.7537
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5009 - accuracy: 0.8255
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6865 - accuracy: 0.7633
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.6499 - accuracy: 0.3970

# %% [markdown]
# Plot the loss curve and smooth it out with Simple Moving Average. The best learning rate is a value that is approximately in the middle of the sharpest downward slope.

# %%
axs = lr_finder.plot_loss()
axs.axvline(x=lr_finder.get_best_lr(sma=20), c='r', linestyle='-.')

# %%
axs = lr_finder.plot_loss_change(sma=20, n_skip_beginning=20, n_skip_end=5, y_lim=(-0.02, 0.04))
axs.axvline(x=lr_finder.get_best_lr(sma=20), c='r', linestyle='-.')
